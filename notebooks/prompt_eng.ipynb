# %% [markdown]
# Split the original data to train and test sets

# %%
import numpy as np

# Step 1: Load data from the input text file
file_path = "../data/data.txt"  # Replace with your file name
data = np.genfromtxt(file_path, delimiter=",", dtype=str)

# Extract labels (assuming labels are in the last column)
labels = data[:, -1]

# Step 2: Split the data into train and test sets weighted by label
unique_labels, counts = np.unique(labels, return_counts=True)
proportions = counts / counts.sum()

train_indices = []
test_indices = []

for label, proportion in zip(unique_labels, proportions):
    label_indices = np.where(labels == label)[0]
    np.random.shuffle(label_indices)
    split_point = int(len(label_indices) * 0.8)  # 80% train, 20% test
    train_indices.extend(label_indices[:split_point])
    test_indices.extend(label_indices[split_point:])

train_indices = np.array(train_indices)
test_indices = np.array(test_indices)

train_data = data[train_indices]
test_data = data[test_indices]

# Step 3: Save the split data into separate .txt files
np.savetxt("../data/train_data.txt", train_data, fmt="%s", delimiter=",")
np.savetxt("../data/test_data.txt", test_data, fmt="%s", delimiter=",")

print("Data successfully split and saved to 'train_data.txt' and 'test_data.txt'.")
# Out:
# Data successfully split and saved to 'train_data.txt' and 'test_data.txt'.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model = 'gemini-pro', temperature = 0.5)

# %%
from langchain_openai import OpenAI

llm=OpenAI(model='gpt-3.5-turbo-instruct', temperature=0.1)

# %%
from langchain_mistralai import ChatMistralAI

llm = ChatMistralAI(model="mistral-large-latest", temperature=0.1)

# %%
# !aws configure
from langchain_aws import ChatBedrock

llm = ChatBedrock(model="amazon.titan-text-express-v1" ,
    beta_use_converse_api=True)

# %%
from langchain_fireworks import ChatFireworks

llm = ChatFireworks(model="accounts/fireworks/models/llama-v3p1-70b-instruct")

# %%
llm
# Out:
# ChatFireworks(client=<fireworks.client.chat_completion.ChatCompletionV2 object at 0x7449ea4fb310>, async_client=<fireworks.client.chat_completion.ChatCompletionV2 object at 0x7449ea4fbe10>, model_name='accounts/fireworks/models/llama-v3p1-70b-instruct', model_kwargs={}, fireworks_api_key=SecretStr('**********'))

# %%
llm.invoke("Hello how are you")
# Out:
# AIMessage(content="Hello! I'm just a computer program, so I don't have feelings, but thanks for asking! How can I assist you today?", additional_kwargs={}, response_metadata={'token_usage': {'prompt_tokens': 19, 'total_tokens': 48, 'completion_tokens': 29}, 'model_name': 'accounts/fireworks/models/llama-v3p1-70b-instruct', 'system_fingerprint': '', 'finish_reason': 'stop', 'logprobs': None}, id='run-513d6b13-5b1a-44f7-a349-08660f76095a-0', usage_metadata={'input_tokens': 19, 'output_tokens': 29, 'total_tokens': 48})

# %%
from langchain.prompts import PromptTemplate

prompt_template = PromptTemplate.from_template(
    '''
    Classify the requirement text into one of the following categories by answering only with the category code (F, A, FT, L, LF, MN, O, PE, PO, SC, SE, or US):
    
-   F (Functional)  : Requirements detailing specific system functionalities or actions.
-   A (Availability)  : Requirements related to system uptime, accessibility, or continuous operation.
-   FT (Fault Tolerance)  : Requirements ensuring the system can handle errors or unexpected failures.
-   L (Legal)  : Requirements concerning compliance with laws, regulations, or industry standards.
-   LF (Look & Feel)  : Requirements about the appearance, design, color schemes, or visual style.
-   MN (Maintainability)  : Requirements on ease of updates, maintenance, or adjustments.
-   O (Operational)  : Requirements on system operations, such as supported platforms or environments.
-   PE (Performance)  : Requirements focused on system speed, response time, or resource efficiency.
-   PO (Portability)  : Requirements related to compatibility across various devices or platforms.
-   SC (Scalability)  : Requirements on the system's ability to handle growth in users or workload.
-   SE (Security)  : Requirements ensuring data security, authorization, or protection from threats.
-   US (Usability)  : Requirements focused on user-friendliness, ease of use, or intuitive design.

---

Now classify this new requirement:{requirement}

Your Answer: just category code (F, A, FT, L, LF, MN, O, PE, PO, SC, SE, or US)
    '''
)

examples = [{
        "question": "The system shall display real-time data updates in a dashboard format accessible to all users.",
        "answer": "F"
    },
    {
        "question": "The product shall maintain 99.5% uptime during business hours, ensuring minimal service interruptions.",
        "answer": "A",
    },
    {
        "question": "The system shall continue to operate normally in case of a single hardware failure.",
        "answer": "FT",
    },
    {
        "question": "The application shall comply with GDPR regulations to ensure data privacy for all EU users.",
        "answer": "L",
    },
    {
        "question": "The product interface shall adhere to corporate branding guidelines, using the approved color palette and typography.",
        "answer": "LF",
    },
    {
        "question": "The system shall allow software updates to be applied without downtime for 95% of maintenance events.",
        "answer": "MN",
    },
    {
        "question": "The product shall support all versions of Windows and Mac operating systems released in the last five years.",
        "answer": "O",
    },
    {
        "question": "The system shall process and return search results within 3 seconds for 90% of user queries.",
        "answer": "PE",
    },
    {
        "question": "The application must be usable on both desktop and mobile devices without a loss of functionality.",
        "answer": "PO",
    },
    {
        "question": "The system shall handle up to 10,000 concurrent users without degradation of performance.",
        "answer": "SC",
    },
    {
        "question": "All user data shall be encrypted in transit and at rest to prevent unauthorized access.",
        "answer": "SE",
    },
    {
        "question": "The product shall allow 90% of first-time users to complete their initial setup within 5 minutes.,",
        "answer": "US",
    },
]

# %%
from langchain.chains import LLMChain
from langchain_core.prompts import FewShotPromptTemplate

chain = LLMChain(
    llm= llm, 
    prompt = prompt_template,
    verbose = False
    )

requirement = "The user interface shall have standard menus  buttons for navigation"



prompt = FewShotPromptTemplate(
    examples=examples,
    example_prompt=prompt_template,
    suffix="Requirement: {input}",
    input_variables=["requirement"],
)

response = chain.invoke(input = requirement)

print(response['text'])
# Out:
# LF

# %%
# File path
file_path = '../data/test_data.txt'

# Read the file
with open(file_path, 'r') as file:
    lines = file.readlines()

# Initialize lists to store separated data
ids = []
texts = []
classes = []

# Process each line
for line in lines:
    # Split the line using a comma as the primary delimiter
    parts = line.split(",", 2)  # Split into 3 parts: ID, text, and class
    if len(parts) == 3:
        ids.append(parts[0].strip())  # First part is the ID
        texts.append(parts[1].strip().strip("'"))  # Second part is the text (strip single quotes)
        classes.append(parts[2].strip())  # Third part is the class

# Combine the lists into a structured format (list of dictionaries)
test = [{"id": id_, "text": text, "class": class_} for id_, text, class_ in zip(ids, texts, classes)]

# Display the first few rows to verify
for row in test[:5]:  # Print only the first 5 rows
    print(row)
# Out:
# {'id': '12', 'text': 'The product shall be available 99% of the time. Rationale: To avoid service interruption during busiest customer service response periods. The product shall be available 99.99% of the time for regular business days.', 'class': 'A'}
# {'id': '37', 'text': 'The software is available for use from the supermarket opening time to the closing time.', 'class': 'A'}
# {'id': '8', 'text': 'The website shall be available for use 24 hours per day  365 days per year.', 'class': 'A'}
# {'id': '8', 'text': 'All movies shall be streamed on demand  at any time of the day.', 'class': 'A'}
# {'id': '3', 'text': 'The system shall be available for use between the hours of 8am and 6pm.', 'class': 'A'}

# %%
import time

output_of_prompt = []

i = 0
while i != len(test):
    try:
        output = chain.invoke(f"{test[i]['text']}")
        output_of_prompt.append({'i':i,
                                'text':test[i]['text'],
                                'labels':test[i]['class'],
                                'prompt_output': output})

        time.sleep(2)
        i += 1
        print(f'{i}/{len(test)} done :)')
    except Exception as e:
        print(f'\n sleep time by 10 seconds for {i}')
        print("Error: ",e)
        time.sleep(10)
# Out:
# 1/198 done :)
# 2/198 done :)
# 3/198 done :)
# 4/198 done :)
# 5/198 done :)
# 6/198 done :)
# 7/198 done :)
# 8/198 done :)
# 9/198 done :)
# 10/198 done :)
# 11/198 done :)
# 12/198 done :)
# 13/198 done :)
# 14/198 done :)
# 15/198 done :)
# 16/198 done :)
# 17/198 done :)
# 18/198 done :)
# 19/198 done :)
# 20/198 done :)
# 21/198 done :)
# 22/198 done :)
# 23/198 done :)
# 24/198 done :)
# 25/198 done :)
# 26/198 done :)
# 27/198 done :)
# 28/198 done :)
# 29/198 done :)
# 30/198 done :)
# 31/198 done :)
# 32/198 done :)
# 33/198 done :)
# 34/198 done :)
# 35/198 done :)
# 36/198 done :)
# 37/198 done :)
# 38/198 done :)
# 39/198 done :)
# 40/198 done :)
# 41/198 done :)
# 42/198 done :)
# 43/198 done :)
# 44/198 done :)
# 45/198 done :)
# 46/198 done :)
# 47/198 done :)
# 48/198 done :)
# 49/198 done :)
# 50/198 done :)
# 51/198 done :)
# 52/198 done :)
# 53/198 done :)
# 54/198 done :)
# 55/198 done :)
# 56/198 done :)
# 57/198 done :)
# 58/198 done :)
# 59/198 done :)
# 60/198 done :)
# 61/198 done :)
# 62/198 done :)
# 63/198 done :)
# 64/198 done :)
# 65/198 done :)
# 66/198 done :)
# 67/198 done :)
# 68/198 done :)
# 69/198 done :)
# 70/198 done :)
# 71/198 done :)
# 72/198 done :)
# 73/198 done :)
# 74/198 done :)
# 75/198 done :)
# 76/198 done :)
# 77/198 done :)
# 78/198 done :)
# 79/198 done :)
# 80/198 done :)
# 81/198 done :)
# 82/198 done :)
# 83/198 done :)
# 84/198 done :)
# 85/198 done :)
# 86/198 done :)
# 87/198 done :)
# 88/198 done :)
# 89/198 done :)
# 90/198 done :)
# 91/198 done :)
# 92/198 done :)
# 93/198 done :)
# 94/198 done :)
# 95/198 done :)
# 96/198 done :)
# 97/198 done :)
# 98/198 done :)
# 99/198 done :)
# 100/198 done :)
# 101/198 done :)
# 102/198 done :)
# 103/198 done :)
# 104/198 done :)
# 105/198 done :)
# 106/198 done :)
# 107/198 done :)
# 108/198 done :)
# 109/198 done :)
# 110/198 done :)
# 111/198 done :)
# 112/198 done :)
# 113/198 done :)
# 114/198 done :)
# 115/198 done :)
# 116/198 done :)
# 117/198 done :)
# 118/198 done :)
# 119/198 done :)
# 120/198 done :)
# 121/198 done :)
# 122/198 done :)
# 123/198 done :)
# 124/198 done :)
# 125/198 done :)
# 126/198 done :)
# 127/198 done :)
# 128/198 done :)
# 129/198 done :)
# 130/198 done :)
# 131/198 done :)
# 132/198 done :)
# 133/198 done :)
# 134/198 done :)
# 135/198 done :)
# 136/198 done :)
# 137/198 done :)
# 138/198 done :)
# 139/198 done :)
# 140/198 done :)
# 141/198 done :)
# 142/198 done :)
# 143/198 done :)
# 144/198 done :)
# 145/198 done :)
# 146/198 done :)
# 147/198 done :)
# 148/198 done :)
# 149/198 done :)
# 150/198 done :)
# 151/198 done :)
# 152/198 done :)
# 153/198 done :)
# 154/198 done :)
# 155/198 done :)
# 156/198 done :)
# 157/198 done :)
# 158/198 done :)
# 159/198 done :)
# 160/198 done :)
# 161/198 done :)
# 162/198 done :)
# 163/198 done :)
# 164/198 done :)
# 165/198 done :)
# 166/198 done :)
# 167/198 done :)
# 168/198 done :)
# 169/198 done :)
# 170/198 done :)
# 171/198 done :)
# 172/198 done :)
# 173/198 done :)
# 174/198 done :)
# 175/198 done :)
# 176/198 done :)
# 177/198 done :)
# 178/198 done :)
# 179/198 done :)
# 180/198 done :)
# 181/198 done :)
# 182/198 done :)
# 183/198 done :)
# 184/198 done :)
# 185/198 done :)
# 186/198 done :)
# 187/198 done :)
# 188/198 done :)
# 189/198 done :)
# 190/198 done :)
# 191/198 done :)
# 192/198 done :)
# 193/198 done :)
# 194/198 done :)
# 195/198 done :)
# 196/198 done :)
# 197/198 done :)
# 198/198 done :)

# %%
output_of_prompt
# Out:
# [{'i': 0,
#   'text': 'The product shall be available 99% of the time. Rationale: To avoid service interruption during busiest customer service response periods. The product shall be available 99.99% of the time for regular business days.',
#   'labels': 'A',
#   'prompt_output': {'requirement': 'The product shall be available 99% of the time. Rationale: To avoid service interruption during busiest customer service response periods. The product shall be available 99.99% of the time for regular business days.',
#    'text': 'A'}},
#  {'i': 1,
#   'text': 'The software is available for use from the supermarket opening time to the closing time.',
#   'labels': 'A',
#   'prompt_output': {'requirement': 'The software is available for use from the supermarket opening time to the closing time.',
#    'text': 'A'}},
#  {'i': 2,
#   'text': 'The website shall be available for use 24 hours per day  365 days per year.',
#   'labels': 'A',
#   'prompt_output': {'requirement': 'The website shall be available for use 24 hours per day  365 days per year.',
#    'text': 'A'}},
#  {'i': 3,
#   'text': 'All movies shall be streamed on demand  at any time of the day.',
#   'labels': 'A',
#   'prompt_output': {'requirement': 'All movies shall be streamed on demand  at any time of the day.',
#    'text': 'F'}},
#  {'i': 4,
#   'text': 'The system shall be available for use between the hours of 8am and 6pm.',
#   'labels': 'A',
#   'prompt_output': {'requirement': 'The system shall be available for use between the hours of 8am and 6pm.',
#    'text': 'A'}},
#  {'i': 5,
#   'text': 'The RFS system should be available 24/7  especially during the budgeting period. The RFS system shall be available 90% of the time all year  and 98% during the budgeting period. 2% of the time  the system will become available within 1 hour of the time that the situation is reported.',
#   'labels': 'A',
#   'prompt_output': {'requirement': 'The RFS system should be available 24/7  especially during the budgeting period. The RFS system shall be available 90% of the time all year  and 98% during the budgeting period. 2% of the time  the system will become available within 1 hour of the time that the situation is reported.',
#    'text': 'A'}},
#  {'i': 6,
#   'text': 'Aside from server failure  the software product shall achieve 99.99% up time.',
#   'labels': 'A',
#   'prompt_output': {'requirement': 'Aside from server failure  the software product shall achieve 99.99% up time.',
#    'text': 'A'}},
#  {'i': 7,
#   'text': 'The system should keep the customer email.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system should keep the customer email.',
#    'text': 'F'}},
#  {'i': 8,
#   'text': 'The estimator shall not apply recycled parts to the collision estimate if no available parts are returned.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The estimator shall not apply recycled parts to the collision estimate if no available parts are returned.',
#    'text': 'F'}},
#  {'i': 9,
#   'text': 'The system shall display available payment methods for payment.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system shall display available payment methods for payment.',
#    'text': 'F'}},
#  {'i': 10,
#   'text': 'Customized information is displayed.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'Customized information is displayed.',
#    'text': 'F'}},
#  {'i': 11,
#   'text': 'Return to List is available if the patient loaded is not correct.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'Return to List is available if the patient loaded is not correct.',
#    'text': 'F'}},
#  {'i': 12,
#   'text': 'The RMS System shall have Windows XP look and feel and use GUI futures making its use intuitive.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The RMS System shall have Windows XP look and feel and use GUI futures making its use intuitive.',
#    'text': 'LF'}},
#  {'i': 13,
#   'text': 'The Disputes System will facilitate direct data entry of a dispute case via a user interface that supports real time responses to the users.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The Disputes System will facilitate direct data entry of a dispute case via a user interface that supports real time responses to the users.',
#    'text': 'F'}},
#  {'i': 14,
#   'text': 'The adjuster shall enter the preferred repair facility on the estimate assignment.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The adjuster shall enter the preferred repair facility on the estimate assignment.',
#    'text': 'F'}},
#  {'i': 15,
#   'text': 'Program Administrators and Nursing Staff Members shall be able to add a single student to a cohort',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'Program Administrators and Nursing Staff Members shall be able to add a single student to a cohort',
#    'text': 'F'}},
#  {'i': 16,
#   'text': 'The system shall update or create new property listings in the MLS',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system shall update or create new property listings in the MLS',
#    'text': 'F'}},
#  {'i': 17,
#   'text': 'Product formula substitutionary ingredients shall be entered automatically by the PFE subsystem.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'Product formula substitutionary ingredients shall be entered automatically by the PFE subsystem.',
#    'text': 'F'}},
#  {'i': 18,
#   'text': 'Enable a registered user to change his password if he forgets his password.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'Enable a registered user to change his password if he forgets his password.',
#    'text': 'F'}},
#  {'i': 19,
#   'text': 'An error message alerts when an invalid patient is entered.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'An error message alerts when an invalid patient is entered.',
#    'text': 'F'}},
#  {'i': 20,
#   'text': 'The system shall allow the user to modify the equipment requirement set of an already submitted meeting response.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system shall allow the user to modify the equipment requirement set of an already submitted meeting response.',
#    'text': 'F'}},
#  {'i': 21,
#   'text': 'The system shall be able to call the seller or buyer to schedule an appointment',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system shall be able to call the seller or buyer to schedule an appointment',
#    'text': 'F'}},
#  {'i': 22,
#   'text': 'The system shall support the ability to perform a send only operation.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system shall support the ability to perform a send only operation.',
#    'text': 'F'}},
#  {'i': 23,
#   'text': 'The top 1/4 of the table will hold events that are to occur sequentially.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The top 1/4 of the table will hold events that are to occur sequentially.',
#    'text': 'F'}},
#  {'i': 24,
#   'text': 'The owner shall have free access to all of the streaming movies.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The owner shall have free access to all of the streaming movies.',
#    'text': 'F'}},
#  {'i': 25,
#   'text': 'The system shall authenticate users at the beginning each session.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system shall authenticate users at the beginning each session.',
#    'text': 'SE'}},
#  {'i': 26,
#   'text': 'The ratings shall include categories for attempted use of recycled parts and actual use of recycled parts',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The ratings shall include categories for attempted use of recycled parts and actual use of recycled parts',
#    'text': 'F'}},
#  {'i': 27,
#   'text': 'System shall automatically update the main page of the website every Friday  and show the 4 latest movies that have been added to the website.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'System shall automatically update the main page of the website every Friday  and show the 4 latest movies that have been added to the website.',
#    'text': 'F'}},
#  {'i': 28,
#   'text': 'The system shall return a list of repair facilities within the radius if the preferred repair facility cannot be determined.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system shall return a list of repair facilities within the radius if the preferred repair facility cannot be determined.',
#    'text': 'F'}},
#  {'i': 29,
#   'text': 'The Disputes System will provide the user the ability to create or initiate a ticket retrieval request.   As part of ticket retrieval creation process the system must prompt the user to enter all the required information to create the ticket retrieval request.  The ticket retrieval request is a document that is sent to merchant inquiring the validity of a transaction.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The Disputes System will provide the user the ability to create or initiate a ticket retrieval request.   As part of ticket retrieval creation process the system must prompt the user to enter all the required information to create the ticket retrieval request.  The ticket retrieval request is a document that is sent to merchant inquiring the validity of a transaction.',
#    'text': 'F'}},
#  {'i': 30,
#   'text': 'Responsible for contacting the banks for the validation of the a/c number provided by the customer while purchasing and make the transaction from the given a/c.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'Responsible for contacting the banks for the validation of the a/c number provided by the customer while purchasing and make the transaction from the given a/c.',
#    'text': 'F'}},
#  {'i': 31,
#   'text': 'Once a game is initiated  the product shall display an offensive grid to each player.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'Once a game is initiated  the product shall display an offensive grid to each player.',
#    'text': 'F'}},
#  {'i': 32,
#   'text': 'The system shall show the meetings to the user in ascending time order by default.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system shall show the meetings to the user in ascending time order by default.',
#    'text': 'F'}},
#  {'i': 33,
#   'text': 'The bottom 3/4 of the table will hold events that occur according to its relevance to current time.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The bottom 3/4 of the table will hold events that occur according to its relevance to current time.',
#    'text': 'F'}},
#  {'i': 34,
#   'text': 'The product shall maintain the status of each player for a turn  either offensive or defensive.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The product shall maintain the status of each player for a turn  either offensive or defensive.',
#    'text': 'F'}},
#  {'i': 35,
#   'text': 'The system shall notify the user about any conflict in the current configuration.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system shall notify the user about any conflict in the current configuration.',
#    'text': 'F'}},
#  {'i': 36,
#   'text': 'For any systematic (non-user initiated) action that occurs on a case such as the disputes aging process  a case activity will be generated.  Upon the next logon the user that initiated the dispute case must be notified that a systematic action has occurred on the dispute case.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'For any systematic (non-user initiated) action that occurs on a case such as the disputes aging process  a case activity will be generated.  Upon the next logon the user that initiated the dispute case must be notified that a systematic action has occurred on the dispute case.',
#    'text': 'F'}},
#  {'i': 37,
#   'text': 'The system shall allow the mediator to solve a location conflict.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system shall allow the mediator to solve a location conflict.',
#    'text': 'F'}},
#  {'i': 38,
#   'text': 'The Disputes System must prevent users from accessing any dispute cases that do not belong to their cardholder base.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The Disputes System must prevent users from accessing any dispute cases that do not belong to their cardholder base.',
#    'text': 'SE'}},
#  {'i': 39,
#   'text': 'The meeting scheduler system may be able to include an agenda for a meeting proposal.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The meeting scheduler system may be able to include an agenda for a meeting proposal.',
#    'text': 'F'}},
#  {'i': 40,
#   'text': 'Website shall allow customers to purchase pre-paid cards of $5  $10  or $20 value either by credit card or mail-in payment option.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'Website shall allow customers to purchase pre-paid cards of $5  $10  or $20 value either by credit card or mail-in payment option.',
#    'text': 'F'}},
#  {'i': 41,
#   'text': 'The System shall allow generation of Inventory Quantity Adjustment documents on demand.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The System shall allow generation of Inventory Quantity Adjustment documents on demand.',
#    'text': 'F'}},
#  {'i': 42,
#   'text': 'Classes for a given cohort shall not conflict with regards to the time and day that they are offered.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'Classes for a given cohort shall not conflict with regards to the time and day that they are offered.',
#    'text': 'F'}},
#  {'i': 43,
#   'text': 'The system will notify affected parties when changes occur affecting specific students  including but not limited to changing a student\\92s status from full time to part time and moving a student to a different clinical section.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system will notify affected parties when changes occur affecting specific students  including but not limited to changing a student\\92s status from full time to part time and moving a student to a different clinical section.',
#    'text': 'F'}},
#  {'i': 44,
#   'text': 'The Disputes System must provide different levels of access with regard to disputes case initiation and follow-up actions.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The Disputes System must provide different levels of access with regard to disputes case initiation and follow-up actions.',
#    'text': 'SE'}},
#  {'i': 45,
#   'text': 'Responsible for managing stocks of each product items.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'Responsible for managing stocks of each product items.',
#    'text': 'F'}},
#  {'i': 46,
#   'text': 'The system shall offer the ability to pause and resume the refresh of data.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system shall offer the ability to pause and resume the refresh of data.',
#    'text': 'F'}},
#  {'i': 47,
#   'text': 'The system shall allow user to select the order from the order history.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system shall allow user to select the order from the order history.',
#    'text': 'F'}},
#  {'i': 48,
#   'text': 'The system shall allow users to view location information.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system shall allow users to view location information.',
#    'text': 'F'}},
#  {'i': 49,
#   'text': 'The physician/pharmacist must have a valid user login to access the system.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The physician/pharmacist must have a valid user login to access the system.',
#    'text': 'SE'}},
#  {'i': 50,
#   'text': 'Once a game has been initiated  the product shall make the players assigned to the game unavailable for selection from the list of players.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'Once a game has been initiated  the product shall make the players assigned to the game unavailable for selection from the list of players.',
#    'text': 'F'}},
#  {'i': 51,
#   'text': 'The leads washing functionality will verify the users authentication and rights to make parameter updates.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The leads washing functionality will verify the users authentication and rights to make parameter updates.',
#    'text': 'SE'}},
#  {'i': 52,
#   'text': 'The system shall display both the active and completed order history in the customer profile.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system shall display both the active and completed order history in the customer profile.',
#    'text': 'F'}},
#  {'i': 53,
#   'text': 'The system shall retain the available recycled parts and suppliers returned from the search.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system shall retain the available recycled parts and suppliers returned from the search.',
#    'text': 'F'}},
#  {'i': 54,
#   'text': 'The System shall generate Inventory Quantity Adjustment document based on product daily sales data and product formulas.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The System shall generate Inventory Quantity Adjustment document based on product daily sales data and product formulas.',
#    'text': 'F'}},
#  {'i': 55,
#   'text': 'The system shall allow user to decorate their doughnut.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system shall allow user to decorate their doughnut.',
#    'text': 'LF'}},
#  {'i': 56,
#   'text': 'The product shall allow the user to save the property search results.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The product shall allow the user to save the property search results.',
#    'text': 'F'}},
#  {'i': 57,
#   'text': 'The system shall allow a Program Administrator or Nursing staff member to remove a student from a clinical lab section.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system shall allow a Program Administrator or Nursing staff member to remove a student from a clinical lab section.',
#    'text': 'F'}},
#  {'i': 58,
#   'text': 'The system shall query the user for the account type.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system shall query the user for the account type.',
#    'text': 'F'}},
#  {'i': 59,
#   'text': 'The system shall notify the use about the financing request.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system shall notify the use about the financing request.',
#    'text': 'F'}},
#  {'i': 60,
#   'text': 'The system shall contain contact information (e-mail and phone number) for all people relevant to the system  including (but not limited to) staff members  students  lecture instructors  clinical lab instructors  and clinical site administrators.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system shall contain contact information (e-mail and phone number) for all people relevant to the system  including (but not limited to) staff members  students  lecture instructors  clinical lab instructors  and clinical site administrators.',
#    'text': 'F'}},
#  {'i': 61,
#   'text': 'If the shot was marked as a miss  the product shall change the status of the offensive player to defensive',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'If the shot was marked as a miss  the product shall change the status of the offensive player to defensive',
#    'text': 'F'}},
#  {'i': 62,
#   'text': 'The system shall allow a Program Administrator/Nursing Staff Member to move a student from one clinical lab section to another clinical lab section corresponding to the same clinical class.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system shall allow a Program Administrator/Nursing Staff Member to move a student from one clinical lab section to another clinical lab section corresponding to the same clinical class.',
#    'text': 'F'}},
#  {'i': 63,
#   'text': 'The leads washing functionality will store any potential lead duplicates returned by the enterprise system.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The leads washing functionality will store any potential lead duplicates returned by the enterprise system.',
#    'text': 'F'}},
#  {'i': 64,
#   'text': 'The system shall allow user to enter the customer and product information for the support.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system shall allow user to enter the customer and product information for the support.',
#    'text': 'F'}},
#  {'i': 65,
#   'text': 'The system shall enable user to navigate between the search results.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system shall enable user to navigate between the search results.',
#    'text': 'F'}},
#  {'i': 66,
#   'text': 'Keep track of all the payment transactions made by the customers and update the payment information.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'Keep track of all the payment transactions made by the customers and update the payment information.',
#    'text': 'F'}},
#  {'i': 67,
#   'text': 'The system shall maintain customer email information as a required part of customer profile.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system shall maintain customer email information as a required part of customer profile.',
#    'text': 'F'}},
#  {'i': 68,
#   'text': 'It should generate a report about registered complaint to the admin and response report to the user who has submitted his queries.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'It should generate a report about registered complaint to the admin and response report to the user who has submitted his queries.',
#    'text': 'F'}},
#  {'i': 69,
#   'text': 'The system shall allow user to choose filling that they want.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system shall allow user to choose filling that they want.',
#    'text': 'F'}},
#  {'i': 70,
#   'text': 'The meeting scheduler system shall reschedule a meeting to support conflict resolutions.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The meeting scheduler system shall reschedule a meeting to support conflict resolutions.',
#    'text': 'F'}},
#  {'i': 71,
#   'text': 'View the personal details of the customer.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'View the personal details of the customer.',
#    'text': 'F'}},
#  {'i': 72,
#   'text': 'The system shall enable user to add one or more component to the configuration.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system shall enable user to add one or more component to the configuration.',
#    'text': 'F'}},
#  {'i': 73,
#   'text': 'The system shall validate the amount is a multiple of $20.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system shall validate the amount is a multiple of $20.',
#    'text': 'F'}},
#  {'i': 74,
#   'text': 'Movies can only be streamed if the customer has purchased a movie  and is within the 2-day time period to stream the movie.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'Movies can only be streamed if the customer has purchased a movie  and is within the 2-day time period to stream the movie.',
#    'text': 'F'}},
#  {'i': 75,
#   'text': 'The recycled parts search results provided to the estimator shall be retrieved by the system.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The recycled parts search results provided to the estimator shall be retrieved by the system.',
#    'text': 'F'}},
#  {'i': 76,
#   'text': 'The product shall make inactive players unavailable for selection from the list of players.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The product shall make inactive players unavailable for selection from the list of players.',
#    'text': 'F'}},
#  {'i': 77,
#   'text': 'The ratings shall be from a scale of 1-10',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The ratings shall be from a scale of 1-10',
#    'text': 'F'}},
#  {'i': 78,
#   'text': 'System shall allow users to update their billing and contact information via the \\93My Account\\94 section of the website.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'System shall allow users to update their billing and contact information via the \\93My Account\\94 section of the website.',
#    'text': 'F'}},
#  {'i': 79,
#   'text': 'The system shall allow user to select the payment method for order.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system shall allow user to select the payment method for order.',
#    'text': 'F'}},
#  {'i': 80,
#   'text': 'The preferred repair facility shall be returned to the user.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The preferred repair facility shall be returned to the user.',
#    'text': 'F'}},
#  {'i': 81,
#   'text': 'A failed login will alert the physician/pharmacist.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'A failed login will alert the physician/pharmacist.',
#    'text': 'F'}},
#  {'i': 82,
#   'text': 'The Disputes System must prevent external users from requesting original receipts. Requests for original receipts are restricted to internal users.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The Disputes System must prevent external users from requesting original receipts. Requests for original receipts are restricted to internal users.',
#    'text': 'SE'}},
#  {'i': 83,
#   'text': 'The Disputes System shall record the name of the user and the date for any activity that creates or modifies the disputes case in the system.  A detailed history of the actions taken on the case  including the date and the user that performed the action must be maintained for auditing purposes.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The Disputes System shall record the name of the user and the date for any activity that creates or modifies the disputes case in the system.  A detailed history of the actions taken on the case  including the date and the user that performed the action must be maintained for auditing purposes.',
#    'text': 'SE'}},
#  {'i': 84,
#   'text': 'Program Administrators/Nursing Staff Members shall have the ability to modify information relating to cohorts including cohort identifier  program of study  preferred sequence of classes and quarters that a cohort will be taking specific classes.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'Program Administrators/Nursing Staff Members shall have the ability to modify information relating to cohorts including cohort identifier  program of study  preferred sequence of classes and quarters that a cohort will be taking specific classes.',
#    'text': 'F'}},
#  {'i': 85,
#   'text': 'The system shall authenticate user credentials to view the profile.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system shall authenticate user credentials to view the profile.',
#    'text': 'SE'}},
#  {'i': 86,
#   'text': 'The system shall allow the user to view pending meetings.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system shall allow the user to view pending meetings.',
#    'text': 'F'}},
#  {'i': 87,
#   'text': 'If the shot was marked as a hit  the product shall allow the offensive player to define a shot.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'If the shot was marked as a hit  the product shall allow the offensive player to define a shot.',
#    'text': 'F'}},
#  {'i': 88,
#   'text': 'The leads washing functionality will have an interface in which lead data parameters can be maintained.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The leads washing functionality will have an interface in which lead data parameters can be maintained.',
#    'text': 'F'}},
#  {'i': 89,
#   'text': 'The product shall notify building personnel of equipment transport requests.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The product shall notify building personnel of equipment transport requests.',
#    'text': 'F'}},
#  {'i': 90,
#   'text': 'The system shall display and embed in each message a date/timestamp of when the message was sent.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system shall display and embed in each message a date/timestamp of when the message was sent.',
#    'text': 'F'}},
#  {'i': 91,
#   'text': 'The system shall notify the user of any schedule changes.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system shall notify the user of any schedule changes.',
#    'text': 'F'}},
#  {'i': 92,
#   'text': 'The system shall display all the matching products based on the search.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system shall display all the matching products based on the search.',
#    'text': 'F'}},
#  {'i': 93,
#   'text': 'The system shall calculate tax for the order.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system shall calculate tax for the order.',
#    'text': 'F'}},
#  {'i': 94,
#   'text': 'The system shall allow the user to register for an account from any page in the system.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The system shall allow the user to register for an account from any page in the system.',
#    'text': 'F'}},
#  {'i': 95,
#   'text': 'The text and time/date of a note that has been entered is displayed starting with most recent.',
#   'labels': 'F',
#   'prompt_output': {'requirement': 'The text and time/date of a note that has been entered is displayed starting with most recent.',
#    'text': 'F'}},
#  {'i': 96,
#   'text': 'ABS shall handle all expected and unexpected errors in ways that prevent loss in information and long downtime period.',
#   'labels': 'FT',
#   'prompt_output': {'requirement': 'ABS shall handle all expected and unexpected errors in ways that prevent loss in information and long downtime period.',
#    'text': 'FT'}},
#  {'i': 97,
#   'text': '100% of saved user preferences shall be restored when system comes back online.',
#   'labels': 'FT',
#   'prompt_output': {'requirement': '100% of saved user preferences shall be restored when system comes back online.',
#    'text': 'FT'}},
#  {'i': 98,
#   'text': 'The website shall continue to operate if the streaming server goes down.',
#   'labels': 'FT',
#   'prompt_output': {'requirement': 'The website shall continue to operate if the streaming server goes down.',
#    'text': 'FT'}},
#  {'i': 99,
#   'text': 'The product and/or dependent databases/filesystems shall remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems shall not crash 100% of the time that malicious data is input into the product.',
#   'labels': 'FT',
#   'prompt_output': {'requirement': 'The product and/or dependent databases/filesystems shall remain operational as a result of the input of malicious data.  The product and/or dependent databases/filesystems shall not crash 100% of the time that malicious data is input into the product.',
#    'text': 'FT'}},
#  {'i': 100,
#   'text': 'The product shall comply with insurance regulations regarding claims processing.',
#   'labels': 'L',
#   'prompt_output': {'requirement': 'The product shall comply with insurance regulations regarding claims processing.',
#    'text': 'L'}},
#  {'i': 101,
#   'text': 'IzognMovies shall meet the licensing requirements set forth by the appropriate organizations in order to stream African movies.',
#   'labels': 'L',
#   'prompt_output': {'requirement': 'IzognMovies shall meet the licensing requirements set forth by the appropriate organizations in order to stream African movies.',
#    'text': 'L'}},
#  {'i': 102,
#   'text': 'The product must comply with Sarbanes-Oxley.',
#   'labels': 'L',
#   'prompt_output': {'requirement': 'The product must comply with Sarbanes-Oxley.',
#    'text': 'L'}},
#  {'i': 103,
#   'text': 'The product shall comply with corporate color scheme',
#   'labels': 'LF',
#   'prompt_output': {'requirement': 'The product shall comply with corporate color scheme',
#    'text': 'LF'}},
#  {'i': 104,
#   'text': 'The logo and the current basic design of registration system should be displayed. The system should be attractive according to the clients. The design and the color should make users feel comfortable when using the system instead of flashing useless colors on the screen. The design should also reflect the seriousness of the environment.',
#   'labels': 'LF',
#   'prompt_output': {'requirement': 'The logo and the current basic design of registration system should be displayed. The system should be attractive according to the clients. The design and the color should make users feel comfortable when using the system instead of flashing useless colors on the screen. The design should also reflect the seriousness of the environment.',
#    'text': 'LF'}},
#  {'i': 105,
#   'text': 'When a shot is marked as a miss  the product shall simulate the sound of a shot missing its target.',
#   'labels': 'LF',
#   'prompt_output': {'requirement': 'When a shot is marked as a miss  the product shall simulate the sound of a shot missing its target.',
#    'text': 'F'}},
#  {'i': 106,
#   'text': 'The system shall be able to display a menu at all times to facilitate manual order taking should the need arise.',
#   'labels': 'LF',
#   'prompt_output': {'requirement': 'The system shall be able to display a menu at all times to facilitate manual order taking should the need arise.',
#    'text': 'F'}},
#  {'i': 107,
#   'text': 'The product shall display each type of ship in a grid using an image of the specific type of ship.',
#   'labels': 'LF',
#   'prompt_output': {'requirement': 'The product shall display each type of ship in a grid using an image of the specific type of ship.',
#    'text': 'LF'}},
#  {'i': 108,
#   'text': 'The system should be simple to use',
#   'labels': 'LF',
#   'prompt_output': {'requirement': 'The system should be simple to use',
#    'text': 'US'}},
#  {'i': 109,
#   'text': 'When a ship is sunk  the product shall simulate the sound of a sinking ship.',
#   'labels': 'LF',
#   'prompt_output': {'requirement': 'When a ship is sunk  the product shall simulate the sound of a sinking ship.',
#    'text': 'F'}},
#  {'i': 110,
#   'text': 'The product shall comply with corporate User Interface Guidelines',
#   'labels': 'LF',
#   'prompt_output': {'requirement': 'The product shall comply with corporate User Interface Guidelines',
#    'text': 'LF'}},
#  {'i': 111,
#   'text': 'The user interface shall have standard menus buttons for navigation',
#   'labels': 'LF',
#   'prompt_output': {'requirement': 'The user interface shall have standard menus buttons for navigation',
#    'text': 'LF'}},
#  {'i': 112,
#   'text': 'The product shall provide GUI based Monitoring Services.System Administrators shall monitor message exchanges will predict and determine problems and will also provide internal and external support.',
#   'labels': 'LF',
#   'prompt_output': {'requirement': 'The product shall provide GUI based Monitoring Services.System Administrators shall monitor message exchanges will predict and determine problems and will also provide internal and external support.',
#    'text': 'F'}},
#  {'i': 113,
#   'text': 'Changes made to the Manage My ID website can be adopted without altering the iOS application.',
#   'labels': 'MN',
#   'prompt_output': {'requirement': 'Changes made to the Manage My ID website can be adopted without altering the iOS application.',
#    'text': 'PO'}},
#  {'i': 114,
#   'text': 'The product must be highly configurable for use with various database management systems for the end users.  80% of end users are able to integrate new database management systems with the product without changing the product\\92s software code.',
#   'labels': 'MN',
#   'prompt_output': {'requirement': 'The product must be highly configurable for use with various database management systems for the end users.  80% of end users are able to integrate new database management systems with the product without changing the product\\92s software code.',
#    'text': 'MN'}},
#  {'i': 115,
#   'text': 'The system should be easy enough to maintain that someone else could do it with a manual and a few hours training.',
#   'labels': 'MN',
#   'prompt_output': {'requirement': 'The system should be easy enough to maintain that someone else could do it with a manual and a few hours training.',
#    'text': 'MN'}},
#  {'i': 116,
#   'text': 'The product shall be expected to operate within the maximum maintenance budget for a minimum of 2 years.',
#   'labels': 'MN',
#   'prompt_output': {'requirement': 'The product shall be expected to operate within the maximum maintenance budget for a minimum of 2 years.',
#    'text': 'MN'}},
#  {'i': 117,
#   'text': 'The customer shall be able to easily integrate new building maps with the product throughout the product\\92s lifecycle.  Integration of new maps with the product shall be possible with little to no support from product support staff.',
#   'labels': 'MN',
#   'prompt_output': {'requirement': 'The customer shall be able to easily integrate new building maps with the product throughout the product\\92s lifecycle.  Integration of new maps with the product shall be possible with little to no support from product support staff.',
#    'text': 'MN'}},
#  {'i': 118,
#   'text': 'The system shall use the SMTP mail protocol.',
#   'labels': 'O',
#   'prompt_output': {'requirement': 'The system shall use the SMTP mail protocol.',
#    'text': 'O'}},
#  {'i': 119,
#   'text': 'The product will be available for licensing as a one-server  two-five servers  or five-or-more servers license.',
#   'labels': 'O',
#   'prompt_output': {'requirement': 'The product will be available for licensing as a one-server  two-five servers  or five-or-more servers license.',
#    'text': 'O'}},
#  {'i': 120,
#   'text': 'The product must be able to interface with various database management systems. The product shall communicate successfully with the database management system on 100% of all transactions.',
#   'labels': 'O',
#   'prompt_output': {'requirement': 'The product must be able to interface with various database management systems. The product shall communicate successfully with the database management system on 100% of all transactions.',
#    'text': 'F'}},
#  {'i': 121,
#   'text': 'The system shall be used within the specifications defined by the computers used by the Program Administrators/Nursing Staff Members.',
#   'labels': 'O',
#   'prompt_output': {'requirement': 'The system shall be used within the specifications defined by the computers used by the Program Administrators/Nursing Staff Members.',
#    'text': 'O'}},
#  {'i': 122,
#   'text': 'The system shall interface with the student master server.',
#   'labels': 'O',
#   'prompt_output': {'requirement': 'The system shall interface with the student master server.',
#    'text': 'F'}},
#  {'i': 123,
#   'text': 'We must be able to interface with any HTML browser.',
#   'labels': 'O',
#   'prompt_output': {'requirement': 'We must be able to interface with any HTML browser.',
#    'text': 'PO'}},
#  {'i': 124,
#   'text': 'The meeting scheduler shall be accessed from the Web.',
#   'labels': 'O',
#   'prompt_output': {'requirement': 'The meeting scheduler shall be accessed from the Web.',
#    'text': 'O'}},
#  {'i': 125,
#   'text': 'The system shall interface with CampusConnect\\92s central server',
#   'labels': 'O',
#   'prompt_output': {'requirement': 'The system shall interface with CampusConnect\\92s central server',
#    'text': 'F'}},
#  {'i': 126,
#   'text': 'The system shall be compatible with the Microsoft Windows Operating System.',
#   'labels': 'O',
#   'prompt_output': {'requirement': 'The system shall be compatible with the Microsoft Windows Operating System.',
#    'text': 'PO'}},
#  {'i': 127,
#   'text': 'The product shall adhere to the corporate Architecture guidelines',
#   'labels': 'O',
#   'prompt_output': {'requirement': 'The product shall adhere to the corporate Architecture guidelines',
#    'text': 'O'}},
#  {'i': 128,
#   'text': ' The Disputes application shall be available 24x7x365  with the exception of the following scheduled maintenance windows.  Monday \\96 Saturday 3:00am to 4:00am EST Sunday 1:00amd to 5:00am EST',
#   'labels': 'O',
#   'prompt_output': {'requirement': ' The Disputes application shall be available 24x7x365  with the exception of the following scheduled maintenance windows.  Monday \\96 Saturday 3:00am to 4:00am EST Sunday 1:00amd to 5:00am EST',
#    'text': 'A'}},
#  {'i': 129,
#   'text': 'The system shall interface with the faculty central server.',
#   'labels': 'O',
#   'prompt_output': {'requirement': 'The system shall interface with the faculty central server.',
#    'text': 'F'}},
#  {'i': 130,
#   'text': 'The Disputes application shall interface with the Cardmember Posting and Billing System.  This will allow the Disputes application to request adjustments to cardmember and merchant\\92s accounts. All adjustment requests must be sent to the Cardmember Posting and Billing System.',
#   'labels': 'O',
#   'prompt_output': {'requirement': 'The Disputes application shall interface with the Cardmember Posting and Billing System.  This will allow the Disputes application to request adjustments to cardmember and merchant\\92s accounts. All adjustment requests must be sent to the Cardmember Posting and Billing System.',
#    'text': 'F'}},
#  {'i': 131,
#   'text': 'The product shall be able to be installed in the specified environment within 1 working day.',
#   'labels': 'O',
#   'prompt_output': {'requirement': 'The product shall be able to be installed in the specified environment within 1 working day.',
#    'text': 'O'}},
#  {'i': 132,
#   'text': 'The product shall be available for distribution via the Internet as a binary or ZIP file.',
#   'labels': 'O',
#   'prompt_output': {'requirement': 'The product shall be available for distribution via the Internet as a binary or ZIP file.',
#    'text': 'O'}},
#  {'i': 133,
#   'text': 'The WCS system shall be run in a Windows environment. The WCS shall be accessed by users through the Internet on an IBM computer running a Windows 2000 or above operating system.',
#   'labels': 'O',
#   'prompt_output': {'requirement': 'The WCS system shall be run in a Windows environment. The WCS shall be accessed by users through the Internet on an IBM computer running a Windows 2000 or above operating system.',
#    'text': 'O'}},
#  {'i': 134,
#   'text': 'Total lead cycle time must be completed in 5 minutes for 90% of lead volume between the business hours of 8AM CST to 8PM CST; then 3 minutes for 99% of lead volume during off business hours.',
#   'labels': 'PE',
#   'prompt_output': {'requirement': 'Total lead cycle time must be completed in 5 minutes for 90% of lead volume between the business hours of 8AM CST to 8PM CST; then 3 minutes for 99% of lead volume during off business hours.',
#    'text': 'PE'}},
#  {'i': 135,
#   'text': 'The maximum wait time for a user navigating from one screen to another within the Disputes application shall be no more than 5 seconds.',
#   'labels': 'PE',
#   'prompt_output': {'requirement': 'The maximum wait time for a user navigating from one screen to another within the Disputes application shall be no more than 5 seconds.',
#    'text': 'PE'}},
#  {'i': 136,
#   'text': 'The system shall refresh the display every 60 seconds.',
#   'labels': 'PE',
#   'prompt_output': {'requirement': 'The system shall refresh the display every 60 seconds.',
#    'text': 'PE'}},
#  {'i': 137,
#   'text': 'The web application shall add no more than 5 seconds of perceivable overhead time to any necessary web and database transaction time.',
#   'labels': 'PE',
#   'prompt_output': {'requirement': 'The web application shall add no more than 5 seconds of perceivable overhead time to any necessary web and database transaction time.',
#    'text': 'PE'}},
#  {'i': 138,
#   'text': 'The product shall provide Dynamic Change Support and Transparent resource addition.The product shall support Transparent Resource addition and Dynamic Change support to provide scalability and avoid service interruptions of more than 1 day.',
#   'labels': 'PE',
#   'prompt_output': {'requirement': 'The product shall provide Dynamic Change Support and Transparent resource addition.The product shall support Transparent Resource addition and Dynamic Change support to provide scalability and avoid service interruptions of more than 1 day.',
#    'text': 'SC'}},
#  {'i': 139,
#   'text': 'The product shall provide Multi-threading and Load Balancing.The product shall provide multi-threading technology as well as load balancing to overcome data load spikes and traffic.',
#   'labels': 'PE',
#   'prompt_output': {'requirement': 'The product shall provide Multi-threading and Load Balancing.The product shall provide multi-threading technology as well as load balancing to overcome data load spikes and traffic.',
#    'text': 'PE'}},
#  {'i': 140,
#   'text': 'The product shall synchronize with the office system every hour.',
#   'labels': 'PE',
#   'prompt_output': {'requirement': 'The product shall synchronize with the office system every hour.',
#    'text': 'F'}},
#  {'i': 141,
#   'text': 'The response time shall be fast enough to maintain the flow of the game.  The response time shall be no more than 2 seconds for 95% of responses and no more than 4% for the remaining responses.',
#   'labels': 'PE',
#   'prompt_output': {'requirement': 'The response time shall be fast enough to maintain the flow of the game.  The response time shall be no more than 2 seconds for 95% of responses and no more than 4% for the remaining responses.',
#    'text': 'PE'}},
#  {'i': 142,
#   'text': 'The recycled parts audit report shall be returned to the user within 10 seconds.  The audit report shall be returned within 10 seconds.',
#   'labels': 'PE',
#   'prompt_output': {'requirement': 'The recycled parts audit report shall be returned to the user within 10 seconds.  The audit report shall be returned within 10 seconds.',
#    'text': 'PE'}},
#  {'i': 143,
#   'text': 'Any interface between a user and the automated system shall have a maximum response time of 5 seconds  unless noted by an exception below.',
#   'labels': 'PE',
#   'prompt_output': {'requirement': 'Any interface between a user and the automated system shall have a maximum response time of 5 seconds  unless noted by an exception below.',
#    'text': 'PE'}},
#  {'i': 144,
#   'text': 'Any page of the application should not take more than 6 seconds to load on a DSL broadband connection.',
#   'labels': 'PE',
#   'prompt_output': {'requirement': 'Any page of the application should not take more than 6 seconds to load on a DSL broadband connection.',
#    'text': 'PE'}},
#  {'i': 145,
#   'text': 'The response shall be fast enough to avoid interrupting the user\\92s flow of thought.  90% of tasks shall complete within 5 seconds.  98% of tasks shall complete within 8 seconds.',
#   'labels': 'PE',
#   'prompt_output': {'requirement': 'The response shall be fast enough to avoid interrupting the user\\92s flow of thought.  90% of tasks shall complete within 5 seconds.  98% of tasks shall complete within 8 seconds.',
#    'text': 'PE'}},
#  {'i': 146,
#   'text': 'The system shall display confirmation messages to users within 4 seconds after the user submits information to the system.',
#   'labels': 'PE',
#   'prompt_output': {'requirement': 'The system shall display confirmation messages to users within 4 seconds after the user submits information to the system.',
#    'text': 'PE'}},
#  {'i': 147,
#   'text': 'The Disputes application shall support 350 concurrent users without any degradation of performance in the application.',
#   'labels': 'PE',
#   'prompt_output': {'requirement': 'The Disputes application shall support 350 concurrent users without any degradation of performance in the application.',
#    'text': 'SC'}},
#  {'i': 148,
#   'text': 'The Web interface should be compatible with standards in order to be usable via all major Web browsers in a wide variety of environments.',
#   'labels': 'PO',
#   'prompt_output': {'requirement': 'The Web interface should be compatible with standards in order to be usable via all major Web browsers in a wide variety of environments.',
#    'text': 'PO'}},
#  {'i': 149,
#   'text': 'The system shall operate on Unix and Windows operating systems.',
#   'labels': 'PO',
#   'prompt_output': {'requirement': 'The system shall operate on Unix and Windows operating systems.',
#    'text': 'O'}},
#  {'i': 150,
#   'text': 'The system should be portable to various operating environments.',
#   'labels': 'PO',
# ...
#   'labels': 'SC',
#   'prompt_output': {'requirement': 'The WCS system shall have the ability to include data for regions outside the United States and be accessed by users outside of the United States if approved by CCR management.',
#    'text': 'PO'}},
#  {'i': 152,
#   'text': 'The product shall be able to handle up to 1500 simultaneous users. The system shall perform with 1500 users as a time.',
#   'labels': 'SC',
#   'prompt_output': {'requirement': 'The product shall be able to handle up to 1500 simultaneous users. The system shall perform with 1500 users as a time.',
#    'text': 'SC'}},
#  {'i': 153,
#   'text': 'The streaming server will support 50 simultaneous streaming connections.',
#   'labels': 'SC',
#   'prompt_output': {'requirement': 'The streaming server will support 50 simultaneous streaming connections.',
#    'text': 'SC'}},
#  {'i': 154,
#   'text': 'The product shall be able to support multiple remote users',
#   'labels': 'SC',
#   'prompt_output': {'requirement': 'The product shall be able to support multiple remote users',
#    'text': 'SC'}},
#  {'i': 155,
#   'text': 'The website shall be capable of supporting 100 000 customers.',
#   'labels': 'SC',
#   'prompt_output': {'requirement': 'The website shall be capable of supporting 100 000 customers.',
#    'text': 'SC'}},
#  {'i': 156,
#   'text': 'The system shall notify customers of changes to its information policy.',
#   'labels': 'SE',
#   'prompt_output': {'requirement': 'The system shall notify customers of changes to its information policy.',
#    'text': 'F'}},
#  {'i': 157,
#   'text': 'All the passwords that are generated or accepted must be stored in database in an encrypted form.',
#   'labels': 'SE',
#   'prompt_output': {'requirement': 'All the passwords that are generated or accepted must be stored in database in an encrypted form.',
#    'text': 'SE'}},
#  {'i': 158,
#   'text': 'Only authorized users shall have access to the portion of the system that interfaces with CampusConnect.',
#   'labels': 'SE',
#   'prompt_output': {'requirement': 'Only authorized users shall have access to the portion of the system that interfaces with CampusConnect.',
#    'text': 'SE'}},
#  {'i': 159,
#   'text': 'The product shall ensure that it can only be accessed by authorized users.  The product will be able to distinguish between authorized and unauthorized users in all access attempts',
#   'labels': 'SE',
#   'prompt_output': {'requirement': 'The product shall ensure that it can only be accessed by authorized users.  The product will be able to distinguish between authorized and unauthorized users in all access attempts',
#    'text': 'SE'}},
#  {'i': 160,
#   'text': 'Patrons shall log in according to the restricted computer system access policy.',
#   'labels': 'SE',
#   'prompt_output': {'requirement': 'Patrons shall log in according to the restricted computer system access policy.',
#    'text': 'SE'}},
#  {'i': 161,
#   'text': 'The system shall use secure socket layer (SSL) technology to ensure all payments made online and user logins are secure.',
#   'labels': 'SE',
#   'prompt_output': {'requirement': 'The system shall use secure socket layer (SSL) technology to ensure all payments made online and user logins are secure.',
#    'text': 'SE'}},
#  {'i': 162,
#   'text': 'The system shall use the organization\\92s standard virus protection software to help monitor threats to itself.',
#   'labels': 'SE',
#   'prompt_output': {'requirement': 'The system shall use the organization\\92s standard virus protection software to help monitor threats to itself.',
#    'text': 'SE'}},
#  {'i': 163,
#   'text': 'The system shall not leave any cookies on the customer’s computer containing the user’s password.',
#   'labels': 'SE',
#   'prompt_output': {'requirement': 'The system shall not leave any cookies on the customer’s computer containing the user’s password.',
#    'text': 'SE'}},
#  {'i': 164,
#   'text': 'A waiter password used for tablet login must be changed every three months.',
#   'labels': 'SE',
#   'prompt_output': {'requirement': 'A waiter password used for tablet login must be changed every three months.',
#    'text': 'SE'}},
#  {'i': 165,
#   'text': 'The application must log the user out when it is exited.',
#   'labels': 'SE',
#   'prompt_output': {'requirement': 'The application must log the user out when it is exited.',
#    'text': 'F'}},
#  {'i': 166,
#   'text': 'The product shall have the ability to receive automatic software updates as new threats emerge. 100% of customers will be able to receive automatic software updates transmitted to the installed product.',
#   'labels': 'SE',
#   'prompt_output': {'requirement': 'The product shall have the ability to receive automatic software updates as new threats emerge. 100% of customers will be able to receive automatic software updates transmitted to the installed product.',
#    'text': 'MN'}},
#  {'i': 167,
#   'text': 'All authorized users  once authenticated must be able to logon to the Disputes System',
#   'labels': 'SE',
#   'prompt_output': {'requirement': 'All authorized users  once authenticated must be able to logon to the Disputes System',
#    'text': 'F'}},
#  {'i': 168,
#   'text': 'The website must provide highest degree of security to the registered users. All the transactions that are made must be secured. The sensitive information passed to and from the website must be secured. Identity theft and other security related issues must be solved. Unauthorized transmission of sensitive information of the user to third party websites for reference must be avoided. On the basis of user agreement the information must be processed. All the information about the registered user must be securely stored in the central database.',
#   'labels': 'SE',
#   'prompt_output': {'requirement': 'The website must provide highest degree of security to the registered users. All the transactions that are made must be secured. The sensitive information passed to and from the website must be secured. Identity theft and other security related issues must be solved. Unauthorized transmission of sensitive information of the user to third party websites for reference must be avoided. On the basis of user agreement the information must be processed. All the information about the registered user must be securely stored in the central database.',
#    'text': 'SE'}},
#  {'i': 169,
#   'text': 'All credit card information will be encrypted in the database.',
#   'labels': 'SE',
#   'prompt_output': {'requirement': 'All credit card information will be encrypted in the database.',
#    'text': 'SE'}},
#  {'i': 170,
#   'text': 'The product shall ensure that only supervisors can advertise empty time slots.The product must ensure that supervisors are allowed to access advertise empty time slots.',
#   'labels': 'SE',
#   'prompt_output': {'requirement': 'The product shall ensure that only supervisors can advertise empty time slots.The product must ensure that supervisors are allowed to access advertise empty time slots.',
#    'text': 'SE'}},
#  {'i': 171,
#   'text': 'System will use secured database.',
#   'labels': 'SE',
#   'prompt_output': {'requirement': 'System will use secured database.',
#    'text': 'SE'}},
#  {'i': 172,
#   'text': 'Information transmission should be securely transmitted to server without any changes in information.',
#   'labels': 'SE',
#   'prompt_output': {'requirement': 'Information transmission should be securely transmitted to server without any changes in information.',
#    'text': 'SE'}},
#  {'i': 173,
#   'text': 'System security and access levels are provided in the online system. There are varying levels of system access and functional authority. Each student’s access is limited to his/her own registration records. Only authorized system administrator(s) has access to all student registration records.',
#   'labels': 'SE',
#   'prompt_output': {'requirement': 'System security and access levels are provided in the online system. There are varying levels of system access and functional authority. Each student’s access is limited to his/her own registration records. Only authorized system administrator(s) has access to all student registration records.',
#    'text': 'SE'}},
#  {'i': 174,
#   'text': 'A customer can only stream a movie if they purchased it  and are within the 2 day viewing period.',
#   'labels': 'SE',
#   'prompt_output': {'requirement': 'A customer can only stream a movie if they purchased it  and are within the 2 day viewing period.',
#    'text': 'F'}},
#  {'i': 175,
#   'text': 'The website shall prevent its data from being corrupted when incorrect data is entered in.',
#   'labels': 'SE',
#   'prompt_output': {'requirement': 'The website shall prevent its data from being corrupted when incorrect data is entered in.',
#    'text': 'FT'}},
#  {'i': 176,
#   'text': 'The software system needs a robust security mechanism in place so that unauthorized users are not allowed access to parts of the system.',
#   'labels': 'SE',
#   'prompt_output': {'requirement': 'The software system needs a robust security mechanism in place so that unauthorized users are not allowed access to parts of the system.',
#    'text': 'SE'}},
#  {'i': 177,
#   'text': 'The Disputes System shall generate a User Report that details any new users that have been added and any changes to an existing user\\92s access level. The report will be reviewed for auditing purposes.',
#   'labels': 'SE',
#   'prompt_output': {'requirement': 'The Disputes System shall generate a User Report that details any new users that have been added and any changes to an existing user\\92s access level. The report will be reviewed for auditing purposes.',
#    'text': 'F'}},
#  {'i': 178,
#   'text': 'The system must automatically log out all customers after a period of inactivity.',
#   'labels': 'SE',
#   'prompt_output': {'requirement': 'The system must automatically log out all customers after a period of inactivity.',
#    'text': 'SE'}},
#  {'i': 179,
#   'text': 'Only adjusters can request recycled parts audit reports. No users without an adjuster role shall request recycled parts audits.',
#   'labels': 'SE',
#   'prompt_output': {'requirement': 'Only adjusters can request recycled parts audit reports. No users without an adjuster role shall request recycled parts audits.',
#    'text': 'SE'}},
#  {'i': 180,
#   'text': 'Every user of the software is provided a unique login ID and a password which is stored in the database hashed by SHA2 algorithm.',
#   'labels': 'SE',
#   'prompt_output': {'requirement': 'Every user of the software is provided a unique login ID and a password which is stored in the database hashed by SHA2 algorithm.',
#    'text': 'SE'}},
#  {'i': 181,
#   'text': '100% of cardmember services representatives shall be able to successfully create a dispute case on the first encounter after completing the training course.',
#   'labels': 'US',
#   'prompt_output': {'requirement': '100% of cardmember services representatives shall be able to successfully create a dispute case on the first encounter after completing the training course.',
#    'text': 'F'}},
#  {'i': 182,
#   'text': 'The user interface of the system should be very user friendly. ',
#   'labels': 'US',
#   'prompt_output': {'requirement': 'The user interface of the system should be very user friendly. ',
#    'text': 'US'}},
#  {'i': 183,
#   'text': 'The product shall be easy to learn by Adjusters and Collision Estimators.  The product shall be learned with two days onsite training',
#   'labels': 'US',
#   'prompt_output': {'requirement': 'The product shall be easy to learn by Adjusters and Collision Estimators.  The product shall be learned with two days onsite training',
#    'text': 'US'}},
#  {'i': 184,
#   'text': 'The product shall be intuitive and self-explanatory. 90% of new users shall be able to start the display of Events or Activities within 90 minutes of using the product.',
#   'labels': 'US',
#   'prompt_output': {'requirement': 'The product shall be intuitive and self-explanatory. 90% of new users shall be able to start the display of Events or Activities within 90 minutes of using the product.',
#    'text': 'US'}},
#  {'i': 185,
#   'text': 'The user shall easily locate instructions while using the product.  User help can be found within 90% of the system.',
#   'labels': 'US',
#   'prompt_output': {'requirement': 'The user shall easily locate instructions while using the product.  User help can be found within 90% of the system.',
#    'text': 'US'}},
#  {'i': 186,
#   'text': 'The system must use a point and click interface. 100% of all selection and navigation functionality must be able to be activated/selected by either a mouse or a keyboard',
#   'labels': 'US',
#   'prompt_output': {'requirement': 'The system must use a point and click interface. 100% of all selection and navigation functionality must be able to be activated/selected by either a mouse or a keyboard',
#    'text': 'US'}},
#  {'i': 187,
#   'text': 'The system must be quickly accessible by both managers and chefs.',
#   'labels': 'US',
#   'prompt_output': {'requirement': 'The system must be quickly accessible by both managers and chefs.',
#    'text': 'US'}},
#  {'i': 188,
#   'text': 'The system shall use symbols and words that are naturally understandable by the user community.',
#   'labels': 'US',
#   'prompt_output': {'requirement': 'The system shall use symbols and words that are naturally understandable by the user community.',
#    'text': 'US'}},
#  {'i': 189,
#   'text': 'It should not take more than 90 seconds for a registered user to place an order.',
#   'labels': 'US',
#   'prompt_output': {'requirement': 'It should not take more than 90 seconds for a registered user to place an order.',
#    'text': 'PE'}},
#  {'i': 190,
#   'text': 'Users shall feel satisfied using the product.  85% of all users will be satisfied with the product.',
#   'labels': 'US',
#   'prompt_output': {'requirement': 'Users shall feel satisfied using the product.  85% of all users will be satisfied with the product.',
#    'text': 'US'}},
#  {'i': 191,
#   'text': 'The product shall make the users want to use it. 80% of the users surveyed report they are regularly using the product after the first 2 weeks post-launch.',
#   'labels': 'US',
#   'prompt_output': {'requirement': 'The product shall make the users want to use it. 80% of the users surveyed report they are regularly using the product after the first 2 weeks post-launch.',
#    'text': 'US'}},
#  {'i': 192,
#   'text': 'The product shall allow the user to select a chosen language from one of the target market countries.',
#   'labels': 'US',
#   'prompt_output': {'requirement': 'The product shall allow the user to select a chosen language from one of the target market countries.',
#    'text': 'F'}},
#  {'i': 193,
#   'text': 'The system shall be used by realtors with no training.',
#   'labels': 'US',
#   'prompt_output': {'requirement': 'The system shall be used by realtors with no training.',
#    'text': 'US'}},
#  {'i': 194,
#   'text': 'The system shall have a help system that offers tips and explanation for each screen and each item on the screens upon demand.',
#   'labels': 'US',
#   'prompt_output': {'requirement': 'The system shall have a help system that offers tips and explanation for each screen and each item on the screens upon demand.',
#    'text': 'US'}},
#  {'i': 195,
#   'text': 'The system must be intuitive and simple in the way it displays all relevant data and relationships.',
#   'labels': 'US',
#   'prompt_output': {'requirement': 'The system must be intuitive and simple in the way it displays all relevant data and relationships.',
#    'text': 'US'}},
#  {'i': 196,
#   'text': 'The product shall be easy for a realtor to learn.',
#   'labels': 'US',
#   'prompt_output': {'requirement': 'The product shall be easy for a realtor to learn.',
#    'text': 'US'}},
#  {'i': 197,
#   'text': 'The product shall be installed by an untrained realtor without recourse to separately-printed instructions.',
#   'labels': 'US',
#   'prompt_output': {'requirement': 'The product shall be installed by an untrained realtor without recourse to separately-printed instructions.',
#    'text': 'US'}}]

# %%
pred_bad = []
label = []
data  = output_of_prompt
for d in data:
    pred_bad.append(d['prompt_output']['text'])
    label.append(d['labels'])

# %%
import re
pred = []

# Process each line
for line in pred_bad:
    # Remove \n and content inside parentheses using regular expressions
    cleaned_line = re.sub(r"\n", "", line)  # Remove newline characters
    cleaned_line = re.sub(r"\s*\(.*?\)", "", cleaned_line)  # Remove content in parentheses
    pred.append(cleaned_line.strip())  # Strip leading and trailing spaces

# %%
import re

def extract_categories(pred, categories):
    """
    Extract valid categories from a list of strings.

    :param pred: List of strings containing text and categories
    :param categories: Set of valid categories
    :return: List of extracted valid categories, with 'Invalid' for unmatched items
    """
    filtered_data = []
    for item in pred:
        # Match any valid category as a standalone word
        match = re.findall(r'\b(' + '|'.join(categories) + r')\b', item)
        if match:
            # Add the first matched category (or all matches if needed)
            filtered_data.append(match[0])
        else:
            filtered_data.append("Invalid")  # Add 'Invalid' if no category is found
    return filtered_data


# List of valid categories
categories = {'F', 'A', 'FT', 'L', 'LF', 'MN', 'O', 'PE', 'PO', 'SC', 'SE', 'US'}

# Extract valid categories
filtered_data = extract_categories(pred, categories)

# Verify the lengths
print(f"Length of pred: {len(pred)}")
print(f"Length of filtered_data: {len(filtered_data)}")

# Output the result
pred = filtered_data
# Out:
# Length of pred: 198
# Length of filtered_data: 198

# %%
import pandas as pd

comparison_df = pd.DataFrame({
    'Pred': pred,
    'Labels': label
})

# Configure pandas to display all rows
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns

# Display the DataFrame
comparison_df
# Out:
#     Pred Labels
# 0      A      A
# 1      A      A
# 2      A      A
# 3      F      A
# 4      A      A
# 5      A      A
# 6      A      A
# 7      F      F
# 8      F      F
# 9      F      F
# 10     F      F
# 11     F      F
# 12    LF      F
# 13     F      F
# 14     F      F
# 15     F      F
# 16     F      F
# 17     F      F
# 18     F      F
# 19     F      F
# 20     F      F
# 21     F      F
# 22     F      F
# 23     F      F
# 24     F      F
# 25    SE      F
# 26     F      F
# 27     F      F
# 28     F      F
# 29     F      F
# 30     F      F
# 31     F      F
# 32     F      F
# 33     F      F
# 34     F      F
# 35     F      F
# 36     F      F
# 37     F      F
# 38    SE      F
# 39     F      F
# 40     F      F
# 41     F      F
# 42     F      F
# 43     F      F
# 44    SE      F
# 45     F      F
# 46     F      F
# 47     F      F
# 48     F      F
# 49    SE      F
# 50     F      F
# 51    SE      F
# 52     F      F
# 53     F      F
# 54     F      F
# 55    LF      F
# 56     F      F
# 57     F      F
# 58     F      F
# 59     F      F
# 60     F      F
# 61     F      F
# 62     F      F
# 63     F      F
# 64     F      F
# 65     F      F
# 66     F      F
# 67     F      F
# 68     F      F
# 69     F      F
# 70     F      F
# 71     F      F
# 72     F      F
# 73     F      F
# 74     F      F
# 75     F      F
# 76     F      F
# 77     F      F
# 78     F      F
# 79     F      F
# 80     F      F
# 81     F      F
# 82    SE      F
# 83    SE      F
# 84     F      F
# 85    SE      F
# 86     F      F
# 87     F      F
# 88     F      F
# 89     F      F
# 90     F      F
# 91     F      F
# 92     F      F
# 93     F      F
# 94     F      F
# 95     F      F
# 96    FT     FT
# 97    FT     FT
# 98    FT     FT
# 99    FT     FT
# 100    L      L
# 101    L      L
# 102    L      L
# 103   LF     LF
# 104   LF     LF
# 105    F     LF
# 106    F     LF
# 107   LF     LF
# 108   US     LF
# 109    F     LF
# 110   LF     LF
# 111   LF     LF
# 112    F     LF
# 113   PO     MN
# 114   MN     MN
# 115   MN     MN
# 116   MN     MN
# 117   MN     MN
# 118    O      O
# 119    O      O
# 120    F      O
# 121    O      O
# 122    F      O
# 123   PO      O
# 124    O      O
# 125    F      O
# 126   PO      O
# 127    O      O
# 128    A      O
# 129    F      O
# 130    F      O
# 131    O      O
# 132    O      O
# 133    O      O
# 134   PE     PE
# 135   PE     PE
# 136   PE     PE
# 137   PE     PE
# 138   SC     PE
# 139   PE     PE
# 140    F     PE
# 141   PE     PE
# 142   PE     PE
# 143   PE     PE
# 144   PE     PE
# 145   PE     PE
# 146   PE     PE
# 147   SC     PE
# 148   PO     PO
# 149    O     PO
# 150   PO     PO
# 151   PO     SC
# 152   SC     SC
# 153   SC     SC
# 154   SC     SC
# 155   SC     SC
# 156    F     SE
# 157   SE     SE
# 158   SE     SE
# 159   SE     SE
# 160   SE     SE
# 161   SE     SE
# 162   SE     SE
# 163   SE     SE
# 164   SE     SE
# 165    F     SE
# 166   MN     SE
# 167    F     SE
# 168   SE     SE
# 169   SE     SE
# 170   SE     SE
# 171   SE     SE
# 172   SE     SE
# 173   SE     SE
# 174    F     SE
# 175   FT     SE
# 176   SE     SE
# 177    F     SE
# 178   SE     SE
# 179   SE     SE
# 180   SE     SE
# 181    F     US
# 182   US     US
# 183   US     US
# 184   US     US
# 185   US     US
# 186   US     US
# 187   US     US
# 188   US     US
# 189   PE     US
# 190   US     US
# 191   US     US
# 192    F     US
# 193   US     US
# 194   US     US
# 195   US     US
# 196   US     US
# 197   US     US

# %%
import numpy as np
from collections import defaultdict

def perf_measure(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)

    if len(y_true) != len(y_pred):
        raise ValueError("The lengths of y_true and y_pred must match.")

    # Get the unique classes
    classes = np.unique(np.concatenate((y_true, y_pred)))

    # Initialize dictionaries to store results
    metrics = {cls: {"TP": 0, "FP": 0, "TN": 0, "FN": 0} for cls in classes}

    for cls in classes:
        metrics[cls]["TP"] = np.sum((y_true == cls) & (y_pred == cls))
        metrics[cls]["FP"] = np.sum((y_true != cls) & (y_pred == cls))
        metrics[cls]["TN"] = np.sum((y_true != cls) & (y_pred != cls))
        metrics[cls]["FN"] = np.sum((y_true == cls) & (y_pred != cls))

    TP = sum(values["TP"] for values in metrics.values())
    FP = sum(values["FP"] for values in metrics.values())
    TN = sum(values["TN"] for values in metrics.values())
    FN = sum(values["FN"] for values in metrics.values())
    return TP, FP, TN, FN

TP, FP, TN, FN = perf_measure(label, pred)

accuracy = (TP + TN) / (TP + FP + TN + FN)
recall = TP / (TP + FN) if (TP + FN) > 0 else 0
precision = TP / (TP + FP) if (TP + FP) > 0 else 0
F1 = (2 * precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

print('Accuracy: ', accuracy)
print('Recall: ', recall)
print('Precision: ', precision)
print('F1-score: ', F1)
# Out:
# Accuracy:  0.9663299663299664
# Recall:  0.797979797979798
# Precision:  0.797979797979798
# F1-score:  0.7979797979797979
